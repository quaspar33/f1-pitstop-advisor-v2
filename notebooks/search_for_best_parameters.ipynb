# %% [markdown]
# # Exploration phase — further testing
# Initial testing of different algorithms has already been completed. XGBRegressor and GradientBoostingRegressor, both tree-based boosting models are clearly the winners. In this phase of exploration, we will further optimize the two so as to train the best possible performance predicting models for each circuit.

# %%
import f1_pitstop_advisor.data_processing_utils as utils
import pandas as pd
import numpy as np
import pickle

from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline

from sklearn.base import clone

import time

# %%
# Load in all sessions
with open("ig_sessions.pickle", "rb") as file:
    sessions = pickle.load(file)

# %%
# Aggregate laps from all sessions to the circuit they were performed on.

# We end up with a dictionary where the keys are circuit names, and the values 
# are DataFrames containing data for all laps for each circuit.
circuits = set()
for session in sessions:
    circuits.add(session.session_info["Meeting"]["Circuit"]["ShortName"])

dfs = {}
for circuit in circuits:
    dfs[circuit] = utils.get_refined_lap_data_with_z_score_for_circuit(sessions, circuit)

# %%
with open("ig_dfs_by_circuit.pickle", "wb") as file:
    pickle.dump(dfs, file)

# %%
with open("ig_initial_models.pickle", "rb") as file:
    tested_models = pickle.load(file)

# %%
# Show data point count for each circuit
circuit_sizes = {}
for circuit, df in dfs.items():
    circuit_sizes[circuit] = df.shape[0]

circuit_sizes = pd.DataFrame({"DataPointCount": circuit_sizes}).sort_values(by="DataPointCount", ascending=False)
circuit_sizes
# Out:
#                     DataPointCount
# Zandvoort                     5486
# Hungaroring                   5357
# Monte Carlo                   5314
# Montreal                      5189
# Catalunya                     5054
# Sakhir                        4414
# Singapore                     4304
# Monza                         3898
# Mexico City                   3843
# Melbourne                     3780
# Silverstone                   3433
# Jeddah                        3430
# Yas Marina Circuit            3307
# Suzuka                        3186
# Baku                          2734
# Imola                         2442
# Miami                         2160
# Las Vegas                     1799
# Spa-Francorchamps             1592
# Spielberg                     1124
# Paul Ricard                    945
# Austin                         918

# %%
best_params = {}
for model_type in ["GradientBoostingRegressor", "XGBRegressor"]:
    best_params[model_type] = {}
    for circuit in dfs.keys():
        best_params[model_type][circuit] = tested_models[model_type][circuit].best_params_

# %%
for model_type, params in best_params.items():
    best_params[model_type] = pd.DataFrame(params).T

# %% [markdown]
# ## Exploring parameters from previous testing
# Below are the best parameters from initial exploration for GradientBoostingRegressor, for each circuit. Based on this we will determine the parameter value ranges to explore when further optimizing the models.

# %%
best_params["GradientBoostingRegressor"]
# Out:
#                     learning_rate  max_depth  n_estimators  subsample
# Miami                        0.10        3.0         200.0        0.8
# Austin                       0.10        3.0         200.0        0.8
# Melbourne                    0.10        5.0         200.0        1.0
# Las Vegas                    0.10        5.0         200.0        0.8
# Mexico City                  0.10        3.0         200.0        1.0
# Jeddah                       0.10        5.0         200.0        0.8
# Yas Marina Circuit           0.10        3.0         100.0        1.0
# Sakhir                       0.10        3.0         200.0        0.8
# Singapore                    0.10        3.0         200.0        0.8
# Imola                        0.05        3.0         200.0        0.8
# Montreal                     0.10        5.0         200.0        1.0
# Spa-Francorchamps            0.10        3.0         100.0        0.8
# Paul Ricard                  0.10        3.0         200.0        1.0
# Silverstone                  0.10        5.0         200.0        0.8
# Baku                         0.10        3.0         200.0        0.8
# Spielberg                    0.05        5.0         100.0        0.8
# Monza                        0.10        5.0         100.0        1.0
# Suzuka                       0.05        3.0         200.0        1.0
# Catalunya                    0.05        5.0         200.0        0.8
# Zandvoort                    0.10        5.0         200.0        1.0
# Monte Carlo                  0.10        5.0         200.0        0.8
# Hungaroring                  0.10        5.0         100.0        0.8

# %% [markdown]
# ### Same for XGBRegressor

# %%
best_params["XGBRegressor"]
# Out:
#                     colsample_bytree  learning_rate  max_depth  n_estimators  \
# Miami                            0.8           0.30        3.0         400.0
# Austin                           1.0           0.10        3.0         400.0
# Melbourne                        0.8           0.10        6.0         400.0
# Las Vegas                        0.8           0.30        3.0         400.0
# Mexico City                      0.8           0.01       10.0         400.0
# Jeddah                           0.8           0.30        3.0         400.0
# Yas Marina Circuit               0.8           0.10        3.0         100.0
# Sakhir                           0.8           0.10        6.0         100.0
# Singapore                        1.0           0.10        3.0         400.0
# Imola                            1.0           0.30        3.0         200.0
# Montreal                         1.0           0.30        3.0         400.0
# Spa-Francorchamps                1.0           0.10        6.0         100.0
# Paul Ricard                      0.8           0.10        3.0         400.0
# Silverstone                      0.8           0.10        3.0         400.0
# Baku                             0.8           0.30        3.0         200.0
# Spielberg                        1.0           0.01        6.0         400.0
# Monza                            0.8           0.01        6.0         400.0
# Suzuka                           0.8           0.10        3.0         200.0
# Catalunya                        0.8           0.01       10.0         400.0
# Zandvoort                        1.0           0.30        3.0         400.0
# Monte Carlo                      0.8           0.01       10.0         400.0
# Hungaroring                      1.0           0.10        6.0         100.0
#
#                     subsample
# Miami                     0.8
# Austin                    0.8
# Melbourne                 0.8
# Las Vegas                 0.8
# Mexico City               0.8
# Jeddah                    1.0
# Yas Marina Circuit        1.0
# Sakhir                    0.8
# Singapore                 1.0
# Imola                     1.0
# Montreal                  1.0
# Spa-Francorchamps         0.8
# Paul Ricard               1.0
# Silverstone               1.0
# Baku                      1.0
# Spielberg                 1.0
# Monza                     1.0
# Suzuka                    0.8
# Catalunya                 1.0
# Zandvoort                 1.0
# Monte Carlo               0.8
# Hungaroring               1.0

# %%
param_ranges = {}
for model_type, param_df in best_params.items():
    param_ranges[model_type] = pd.DataFrame({
        "Min": param_df.min(axis="index"),
        "Max": param_df.max(axis="index")
    })

# %% [markdown]
# Below we look at the exact parameter value ranges for both regression algorithms:

# %%
param_ranges["GradientBoostingRegressor"]
# Out:
#                   Min    Max
# learning_rate    0.05    0.1
# max_depth        3.00    5.0
# n_estimators   100.00  200.0
# subsample        0.80    1.0

# %%
param_ranges["XGBRegressor"]
# Out:
#                      Min    Max
# colsample_bytree    0.80    1.0
# learning_rate       0.01    0.3
# max_depth           3.00   10.0
# n_estimators      100.00  400.0
# subsample           0.80    1.0

# %% [markdown]
# ## Parameter search grids
# Based on the above, I came up with the grid searches below. These will be trained to find the best
# parameters for each model, for each circuit.

# %%
model_searches = {
    "GradientBoostingRegressor": GridSearchCV(
        GradientBoostingRegressor(random_state=42),
        {
            "n_estimators": [100, 150, 200],
            "learning_rate": [0.05, 0.1],
            "max_depth": [3, 4, 5],
            "subsample": [0.8, 0.9, 1.0],
            "min_samples_leaf": [1, 3]
        }
    ),

    "XGBRegressor": GridSearchCV(
        XGBRegressor(random_state=42, n_jobs=-1, objective="reg:squarederror", verbosity=0),
        {
            "n_estimators": [100, 200, 300, 400],
            "max_depth": [3, 6, 10],
            "learning_rate": [0.01, 0.1, 0.3],
            "subsample": [0.8, 1.0],
            "colsample_bytree": [0.8, 1.0],
            "min_child_weight": [1, 3]
        }
    ),
}

# %%
# Fit every single circuit/GridSearch configuration
models_and_circuits = {}

for name in model_searches.keys():
    models_and_circuits[name] = {}

for circuit, data in dfs.items():
    print(f"Fitting models for {circuit}")
    circuit_start = time.time()
    
    X, y = data.drop(["LapTimeZScore"], axis="columns"), data["LapTimeZScore"]
    for name, model_search in model_searches.items():
        print(f"Fitting {name};".ljust(50), end="")
        model_start = time.time()

        model_search_copy = clone(model_search)
        model_search_copy.fit(X, y)
        models_and_circuits[name][circuit] = model_search_copy

        print(f"took {round(time.time() - model_start, 2)} seconds")
    
    print(f"Took a total of {round(time.time() - circuit_start, 2)} seconds to fit all models for circuit \"{circuit}\"")
    print()
# Out:
# Fitting models for Miami
# Fitting GradientBoostingRegressor;                took 231.22 seconds
# Fitting XGBRegressor;                             took 539.47 seconds
# Took a total of 770.69 seconds to fit all models for circuit "Miami"
#
# Fitting models for Austin
# Fitting GradientBoostingRegressor;                took 129.77 seconds
# Fitting XGBRegressor;                             took 455.44 seconds
# Took a total of 585.2 seconds to fit all models for circuit "Austin"
#
# Fitting models for Melbourne
# Fitting GradientBoostingRegressor;                took 648.63 seconds
# Fitting XGBRegressor;                             took 747.75 seconds
# Took a total of 1396.38 seconds to fit all models for circuit "Melbourne"
#
# Fitting models for Las Vegas
# Fitting GradientBoostingRegressor;                took 309.06 seconds
# Fitting XGBRegressor;                             took 506.54 seconds
# Took a total of 815.61 seconds to fit all models for circuit "Las Vegas"
#
# Fitting models for Mexico City
# Fitting GradientBoostingRegressor;                took 455.61 seconds
# Fitting XGBRegressor;                             took 628.5 seconds
# Took a total of 1084.12 seconds to fit all models for circuit "Mexico City"
#
# Fitting models for Jeddah
# Fitting GradientBoostingRegressor;                took 357.04 seconds
# Fitting XGBRegressor;                             took 564.8 seconds
# Took a total of 921.85 seconds to fit all models for circuit "Jeddah"
#
# Fitting models for Yas Marina Circuit
# Fitting GradientBoostingRegressor;                took 334.14 seconds
# Fitting XGBRegressor;                             took 519.18 seconds
# Took a total of 853.32 seconds to fit all models for circuit "Yas Marina Circuit"
#
# Fitting models for Sakhir
# Fitting GradientBoostingRegressor;                took 474.93 seconds
# Fitting XGBRegressor;                             took 647.53 seconds
# Took a total of 1122.47 seconds to fit all models for circuit "Sakhir"
#
# Fitting models for Singapore
# Fitting GradientBoostingRegressor;                took 468.65 seconds
# Fitting XGBRegressor;                             took 551.32 seconds
# Took a total of 1019.97 seconds to fit all models for circuit "Singapore"
#
# Fitting models for Imola
# Fitting GradientBoostingRegressor;                took 239.4 seconds
# Fitting XGBRegressor;                             took 500.85 seconds
# Took a total of 740.25 seconds to fit all models for circuit "Imola"
#
# Fitting models for Montreal
# Fitting GradientBoostingRegressor;                took 623.74 seconds
# Fitting XGBRegressor;                             took 668.51 seconds
# Took a total of 1292.26 seconds to fit all models for circuit "Montreal"
#
# Fitting models for Spa-Francorchamps
# Fitting GradientBoostingRegressor;                took 171.38 seconds
# Fitting XGBRegressor;                             took 412.59 seconds
# Took a total of 583.97 seconds to fit all models for circuit "Spa-Francorchamps"
#
# Fitting models for Paul Ricard
# Fitting GradientBoostingRegressor;                took 113.85 seconds
# Fitting XGBRegressor;                             took 309.09 seconds
# Took a total of 422.94 seconds to fit all models for circuit "Paul Ricard"
#
# Fitting models for Silverstone
# Fitting GradientBoostingRegressor;                took 357.22 seconds
# Fitting XGBRegressor;                             took 549.75 seconds
# Took a total of 906.97 seconds to fit all models for circuit "Silverstone"
#
# Fitting models for Baku
# Fitting GradientBoostingRegressor;                took 261.79 seconds
# Fitting XGBRegressor;                             took 511.57 seconds
# Took a total of 773.36 seconds to fit all models for circuit "Baku"
#
# Fitting models for Spielberg
# Fitting GradientBoostingRegressor;                took 133.35 seconds
# Fitting XGBRegressor;                             took 338.23 seconds
# Took a total of 471.59 seconds to fit all models for circuit "Spielberg"
#
# Fitting models for Monza
# Fitting GradientBoostingRegressor;                took 394.29 seconds
# Fitting XGBRegressor;                             took 559.03 seconds
# Took a total of 953.33 seconds to fit all models for circuit "Monza"
#
# Fitting models for Suzuka
# Fitting GradientBoostingRegressor;                took 317.23 seconds
# Fitting XGBRegressor;                             took 515.83 seconds
# Took a total of 833.06 seconds to fit all models for circuit "Suzuka"
#
# Fitting models for Catalunya
# Fitting GradientBoostingRegressor;                took 595.13 seconds
# Fitting XGBRegressor;                             took 682.74 seconds
# Took a total of 1277.88 seconds to fit all models for circuit "Catalunya"
#
# Fitting models for Zandvoort
# Fitting GradientBoostingRegressor;                took 637.43 seconds
# Fitting XGBRegressor;                             took 633.77 seconds
# Took a total of 1271.21 seconds to fit all models for circuit "Zandvoort"
#
# Fitting models for Monte Carlo
# Fitting GradientBoostingRegressor;                took 649.75 seconds
# Fitting XGBRegressor;                             took 674.62 seconds
# Took a total of 1324.37 seconds to fit all models for circuit "Monte Carlo"
#
# Fitting models for Hungaroring
# Fitting GradientBoostingRegressor;                took 660.91 seconds
# Fitting XGBRegressor;                             took 650.96 seconds
# Took a total of 1311.88 seconds to fit all models for circuit "Hungaroring"

# %%
with open("ig_second_models.pickle", "wb") as file:
    pickle.dump(models_and_circuits, file)

# %% [markdown]
# ## Results
# Below are the results of our testing. R^2 is used for score. XGBRegressor generally performs better, but for some circuits, GradientBoostingRegressor gets better scores.

# %%
# Show scores for each GridSearch and circuit
all_scores = {}
for key in models_and_circuits.keys():
    scores = {}
    for circuit, model in models_and_circuits[key].items():
        scores[circuit] = model.best_score_
    all_scores[key] = scores

all_scores: pd.DataFrame = pd.DataFrame(all_scores)

all_scores
# Out:
#                     GradientBoostingRegressor  XGBRegressor
# Miami                                0.817214      0.826405
# Austin                               0.920322      0.920174
# Melbourne                            0.864192      0.868024
# Las Vegas                            0.851970      0.854329
# Mexico City                          0.829232      0.854387
# Jeddah                               0.840661      0.844275
# Yas Marina Circuit                   0.825207      0.817980
# Sakhir                               0.725395      0.740442
# Singapore                            0.558237      0.647718
# Imola                                0.842252      0.841116
# Montreal                             0.848070      0.859711
# Spa-Francorchamps                    0.901266      0.901759
# Paul Ricard                          0.887517      0.895166
# Silverstone                          0.817301      0.817017
# Baku                                 0.718906      0.724952
# Spielberg                            0.952800      0.952972
# Monza                                0.650490      0.671248
# Suzuka                               0.827014      0.833135
# Catalunya                            0.714209      0.727230
# Zandvoort                            0.865595      0.864296
# Monte Carlo                          0.853451      0.875379
# Hungaroring                          0.804080      0.806812

# %% [markdown]
# Overall statistics for both algorithms. XGBRegressor is generally better.

# %%
# Show score statistics for each model
# MinScore is very important. A good model should perform reasonably well for all tracks.
model_scores_df = pd.DataFrame({
    "MeanScore": all_scores.mean(axis="index"),
    "MedianScore": all_scores.median(axis="index"),
    "ScoreVariance": all_scores.var(axis="index"),
    "MinScore": all_scores.min(axis="index")
})

model_scores_df.sort_values(by=["MeanScore"], ascending=False)
# Out:
#                            MeanScore  MedianScore  ScoreVariance  MinScore
# XGBRegressor                0.824751     0.842696       0.006097  0.647718
# GradientBoostingRegressor   0.814336     0.834946       0.008290  0.558237

# %%
# Drop BestModelType if it already exists
all_scores.drop(labels=["BestModelType"], axis="columns", inplace=True, errors="ignore")
all_scores["BestModelType"] = all_scores.idxmax(axis="columns")
all_scores
# Out:
#                     GradientBoostingRegressor  XGBRegressor  \
# Miami                                0.817214      0.826405
# Austin                               0.920322      0.920174
# Melbourne                            0.864192      0.868024
# Las Vegas                            0.851970      0.854329
# Mexico City                          0.829232      0.854387
# Jeddah                               0.840661      0.844275
# Yas Marina Circuit                   0.825207      0.817980
# Sakhir                               0.725395      0.740442
# Singapore                            0.558237      0.647718
# Imola                                0.842252      0.841116
# Montreal                             0.848070      0.859711
# Spa-Francorchamps                    0.901266      0.901759
# Paul Ricard                          0.887517      0.895166
# Silverstone                          0.817301      0.817017
# Baku                                 0.718906      0.724952
# Spielberg                            0.952800      0.952972
# Monza                                0.650490      0.671248
# Suzuka                               0.827014      0.833135
# Catalunya                            0.714209      0.727230
# Zandvoort                            0.865595      0.864296
# Monte Carlo                          0.853451      0.875379
# Hungaroring                          0.804080      0.806812
#
#                                 BestModelType
# Miami                            XGBRegressor
# Austin              GradientBoostingRegressor
# Melbourne                        XGBRegressor
# Las Vegas                        XGBRegressor
# Mexico City                      XGBRegressor
# Jeddah                           XGBRegressor
# Yas Marina Circuit  GradientBoostingRegressor
# Sakhir                           XGBRegressor
# Singapore                        XGBRegressor
# Imola               GradientBoostingRegressor
# Montreal                         XGBRegressor
# Spa-Francorchamps                XGBRegressor
# Paul Ricard                      XGBRegressor
# Silverstone         GradientBoostingRegressor
# Baku                             XGBRegressor
# Spielberg                        XGBRegressor
# Monza                            XGBRegressor
# Suzuka                           XGBRegressor
# Catalunya                        XGBRegressor
# Zandvoort           GradientBoostingRegressor
# Monte Carlo                      XGBRegressor
# Hungaroring                      XGBRegressor

# %% [markdown]
# Finally, we export the chosen models to a file for further use. The file contains a Python dictionary, where the keys are circuit names, and the values are the best model for each track. For most circuits, that will be an XGBRegressor, for others — a GradientBoostingRegressor.

# %%
final_regressor_dictionary = {}
for circuit in all_scores.index:
    best_model_type = all_scores.loc[circuit, "BestModelType"]
    final_regressor_dictionary[circuit] = models_and_circuits[best_model_type][circuit].best_estimator_

# %%
with open("ig_best_models_by_circuit.pickle", "wb") as file:
    pickle.dump(final_regressor_dictionary, file)
