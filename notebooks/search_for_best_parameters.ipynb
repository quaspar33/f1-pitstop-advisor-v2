# %% [markdown]
# # Exploration phase — further testing
# Initial testing of different algorithms has already been completed. XGBRegressor and GradientBoostingRegressor, both tree-based boosting models are clearly the winners. In this phase of exploration, we will further optimize the two so as to train the best possible performance predicting models for each circuit.

# %%
import time
from pathlib import Path

import pandas as pd
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.base import clone
from xgboost import XGBRegressor
# Out:
# [11/12/25 11:56:22] INFO     Using                                                                  ]8;id=414173;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=614373;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/pyt
#                              hon3.11/site-packages/kedro/framework/project/rich_logging.yml' as
#                              logging configuration.

# %%
project_path = Path.cwd().parent
bootstrap_project(project_path)
print(f"Ścieżka projektu: {project_path}")
# Out:
# Ścieżka projektu: /Users/kacperziebacz/Desktop/f1-pitstop-advisor-v2

# %%
with KedroSession.create(project_path=project_path) as session:
    context = session.load_context()

# %%
dfs = context.catalog.load("circuit_lap_data")

print(f"Załadowano dane dla {len(dfs)} torów:")
for circuit, df in dfs.items():
    print(f"  {circuit}: {df.shape[0]} okrążeń, {df.shape[1]} cech")
# Out:
# [11/12/25 11:56:23] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=125590;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=40290;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py#243\243]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     INFO     Loading data from circuit_lap_data (PickleDataset)...             ]8;id=43440;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=936324;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
# Załadowano dane dla 22 torów:
#   Catalunya: 5034 okrążeń, 14 cech
#   Spa-Francorchamps: 1592 okrążeń, 14 cech
#   Silverstone: 2495 okrążeń, 14 cech
#   Singapore: 3778 okrążeń, 14 cech
#   Hungaroring: 4951 okrążeń, 14 cech
#   Suzuka: 2754 okrążeń, 14 cech
#   Paul Ricard: 945 okrążeń, 14 cech
#   Austin: 918 okrążeń, 14 cech
#   Miami: 2160 okrążeń, 14 cech
#   Zandvoort: 5035 okrążeń, 14 cech
#   Monte Carlo: 4244 okrążeń, 14 cech
#   Montreal: 4307 okrążeń, 14 cech
#   Monza: 3898 okrążeń, 14 cech
#   Melbourne: 3071 okrążeń, 14 cech
#   Spielberg: 1124 okrążeń, 14 cech
#   Sakhir: 4415 okrążeń, 14 cech
#   Imola: 2442 okrążeń, 14 cech
#   Baku: 2734 okrążeń, 14 cech
#   Mexico City: 3843 okrążeń, 14 cech
#   Jeddah: 3430 okrążeń, 14 cech
#   Yas Marina Circuit: 3307 okrążeń, 14 cech
#   Las Vegas: 1799 okrążeń, 14 cech

# %%
tested_models = context.catalog.load("initial_models")
# Out:
# [11/12/25 11:56:24] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=195214;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=219326;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py#243\243]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     INFO     Loading data from initial_models (PickleDataset)...               ]8;id=387666;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=883027;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\

# %%
# Show data point count for each circuit
circuit_sizes = {}
for circuit, df in dfs.items():
    circuit_sizes[circuit] = df.shape[0]

circuit_sizes = pd.DataFrame({"DataPointCount": circuit_sizes}).sort_values(
    by="DataPointCount", ascending=False
)
circuit_sizes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                     DataPointCount
# Zandvoort                     5035
# Catalunya                     5034
# Hungaroring                   4951
# Sakhir                        4415
# Montreal                      4307
# Monte Carlo                   4244
# Monza                         3898
# Mexico City                   3843
# Singapore                     3778
# Jeddah                        3430
# Yas Marina Circuit            3307
# Melbourne                     3071
# Suzuka                        2754
# Baku                          2734
# Silverstone                   2495
# Imola                         2442
# Miami                         2160
# Las Vegas                     1799
# Spa-Francorchamps             1592
# Spielberg                     1124
# Paul Ricard                    945
# Austin                         918

# %%
best_params = {}
for model_type in ["GradientBoostingRegressor", "XGBRegressor"]:
    best_params[model_type] = {}
    for circuit in dfs.keys():
        best_params[model_type][circuit] = tested_models[model_type][
            circuit
        ].best_params_

# %%
for model_type, params in best_params.items():
    best_params[model_type] = pd.DataFrame(params).T

# %% [markdown]
# ## Exploring parameters from previous testing
# Below are the best parameters from initial exploration for GradientBoostingRegressor, for each circuit. Based on this we will determine the parameter value ranges to explore when further optimizing the models.

# %%
best_params["GradientBoostingRegressor"]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                     learning_rate  max_depth  n_estimators  subsample
# Catalunya                    0.05        5.0         100.0        0.8
# Spa-Francorchamps            0.05        3.0         200.0        1.0
# Silverstone                  0.10        3.0         200.0        0.8
# Singapore                    0.10        3.0         200.0        1.0
# Hungaroring                  0.01        5.0         100.0        0.8
# Suzuka                       0.05        3.0         200.0        0.8
# Paul Ricard                  0.10        3.0         200.0        1.0
# Austin                       0.10        3.0         200.0        0.8
# Miami                        0.10        3.0         200.0        0.8
# Zandvoort                    0.10        5.0         200.0        0.8
# Monte Carlo                  0.01        3.0         200.0        1.0
# Montreal                     0.10        5.0         200.0        0.8
# Monza                        0.10        5.0         100.0        1.0
# Melbourne                    0.10        5.0         200.0        0.8
# Spielberg                    0.05        5.0         100.0        0.8
# Sakhir                       0.10        5.0         100.0        0.8
# Imola                        0.10        3.0         200.0        1.0
# Baku                         0.10        3.0         200.0        0.8
# Mexico City                  0.10        3.0         200.0        1.0
# Jeddah                       0.10        5.0         200.0        0.8
# Yas Marina Circuit           0.10        3.0         100.0        1.0
# Las Vegas                    0.10        5.0         200.0        0.8

# %% [markdown]
# ### Same for XGBRegressor

# %%
best_params["XGBRegressor"]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                     colsample_bytree  learning_rate  max_depth  n_estimators  \
# Catalunya                        0.8           0.01        6.0         400.0
# Spa-Francorchamps                0.8           0.10        3.0         100.0
# Silverstone                      0.8           0.30        3.0         200.0
# Singapore                        1.0           0.10       10.0         100.0
# Hungaroring                      1.0           0.01       10.0         200.0
# Suzuka                           1.0           0.10        3.0         200.0
# Paul Ricard                      0.8           0.10        3.0         400.0
# Austin                           1.0           0.30        3.0         200.0
# Miami                            0.8           0.30        3.0         100.0
# Zandvoort                        1.0           0.30        3.0         400.0
# Monte Carlo                      1.0           0.01       10.0         400.0
# Montreal                         0.8           0.01       10.0         400.0
# Monza                            0.8           0.01       10.0         400.0
# Melbourne                        1.0           0.30        3.0         400.0
# Spielberg                        1.0           0.01        6.0         400.0
# Sakhir                           0.8           0.10        3.0         400.0
# Imola                            1.0           0.10        3.0         400.0
# Baku                             0.8           0.10        6.0         100.0
# Mexico City                      0.8           0.10        6.0         100.0
# Jeddah                           0.8           0.10        6.0         400.0
# Yas Marina Circuit               0.8           0.10        3.0         100.0
# Las Vegas                        1.0           0.30        3.0         200.0
#
#                     subsample
# Catalunya                 0.8
# Spa-Francorchamps         0.8
# Silverstone               1.0
# Singapore                 1.0
# Hungaroring               0.8
# Suzuka                    1.0
# Paul Ricard               1.0
# Austin                    0.8
# Miami                     0.8
# Zandvoort                 0.8
# Monte Carlo               1.0
# Montreal                  0.8
# Monza                     1.0
# Melbourne                 1.0
# Spielberg                 1.0
# Sakhir                    0.8
# Imola                     0.8
# Baku                      0.8
# Mexico City               0.8
# Jeddah                    0.8
# Yas Marina Circuit        1.0
# Las Vegas                 0.8

# %%
param_ranges = {}
for model_type, param_df in best_params.items():
    param_ranges[model_type] = pd.DataFrame(
        {"Min": param_df.min(axis="index"), "Max": param_df.max(axis="index")}
    )

# %% [markdown]
# Below we look at the exact parameter value ranges for both regression algorithms:

# %%
param_ranges["GradientBoostingRegressor"]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                   Min    Max
# learning_rate    0.01    0.1
# max_depth        3.00    5.0
# n_estimators   100.00  200.0
# subsample        0.80    1.0

# %%
param_ranges["XGBRegressor"]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                      Min    Max
# colsample_bytree    0.80    1.0
# learning_rate       0.01    0.3
# max_depth           3.00   10.0
# n_estimators      100.00  400.0
# subsample           0.80    1.0

# %% [markdown]
# ## Parameter search grids
# Based on the above, I came up with the grid searches below. These will be trained to find the best
# parameters for each model, for each circuit.

# %%
model_searches = {
    "GradientBoostingRegressor": GridSearchCV(
        GradientBoostingRegressor(random_state=42),
        {
            "n_estimators": [100, 150, 200],
            "learning_rate": [0.05, 0.1],
            "max_depth": [3, 4, 5],
            "subsample": [0.8, 0.9, 1.0],
            "min_samples_leaf": [1, 3],
        },
    ),
    "XGBRegressor": GridSearchCV(
        XGBRegressor(
            random_state=42, n_jobs=-1, objective="reg:squarederror", verbosity=0
        ),
        {
            "n_estimators": [100, 200, 300, 400],
            "max_depth": [3, 6, 10],
            "learning_rate": [0.01, 0.1, 0.3],
            "subsample": [0.8, 1.0],
            "colsample_bytree": [0.8, 1.0],
            "min_child_weight": [1, 3],
        },
    ),
}

# %%
# Fit every single circuit/GridSearch configuration
models_and_circuits = {}

for name in model_searches.keys():
    models_and_circuits[name] = {}

for circuit, data in dfs.items():
    print(f"Fitting models for {circuit}")
    circuit_start = time.time()

    # Usuń LapTimeZScore i tekstową kolumnę Compound
    X = data.drop(["LapTimeZScore", "Compound"], axis="columns")
    y = data["LapTimeZScore"]

    print(f"  Shape: {X.shape}, Kolumny: {list(X.columns)}")

    mask = ~y.isna()
    X = X[mask]
    y = y[mask]

    imputer = SimpleImputer(strategy='mean')
    X_imputed = imputer.fit_transform(X)
    X = pd.DataFrame(X_imputed, columns=X.columns, index=X.index)

    print(f"  Shape po imputacji: {X.shape}")

    for name, model_search in model_searches.items():
        print(f"Fitting {name};".ljust(50), end="")
        model_start = time.time()

        model_search_copy = clone(model_search)
        model_search_copy.fit(X, y)
        models_and_circuits[name][circuit] = model_search_copy

        print(f"took {round(time.time() - model_start, 2)} seconds")

    print(
        f'Took a total of {round(time.time() - circuit_start, 2)} seconds to fit all models for circuit "{circuit}"\n'
    )
# Out:
# Fitting models for Catalunya
#   Shape: (5034, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (5034, 12)
# Fitting GradientBoostingRegressor;                took 196.64 seconds
# Fitting XGBRegressor;                             took 425.7 seconds
# Took a total of 622.35 seconds to fit all models for circuit "Catalunya"
#
# Fitting models for Spa-Francorchamps
#   Shape: (1592, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (1592, 12)
# Fitting GradientBoostingRegressor;                took 60.9 seconds
# Fitting XGBRegressor;                             took 395.75 seconds
# Took a total of 456.65 seconds to fit all models for circuit "Spa-Francorchamps"
#
# Fitting models for Silverstone
#   Shape: (2495, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (2495, 12)
# Fitting GradientBoostingRegressor;                took 94.73 seconds
# Fitting XGBRegressor;                             took 401.38 seconds
# Took a total of 496.12 seconds to fit all models for circuit "Silverstone"
#
# Fitting models for Singapore
#   Shape: (3778, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (3778, 12)
# Fitting GradientBoostingRegressor;                took 137.43 seconds
# Fitting XGBRegressor;                             took 400.42 seconds
# Took a total of 537.85 seconds to fit all models for circuit "Singapore"
#
# Fitting models for Hungaroring
#   Shape: (4951, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (4951, 12)
# Fitting GradientBoostingRegressor;                took 187.78 seconds
# Fitting XGBRegressor;                             took 430.96 seconds
# Took a total of 618.75 seconds to fit all models for circuit "Hungaroring"
#
# Fitting models for Suzuka
#   Shape: (2754, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (2754, 12)
# Fitting GradientBoostingRegressor;                took 102.07 seconds
# Fitting XGBRegressor;                             took 410.09 seconds
# Took a total of 512.16 seconds to fit all models for circuit "Suzuka"
#
# Fitting models for Paul Ricard
#   Shape: (945, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (945, 12)
# Fitting GradientBoostingRegressor;                took 35.27 seconds
# Fitting XGBRegressor;                             took 379.36 seconds
# Took a total of 414.62 seconds to fit all models for circuit "Paul Ricard"
#
# Fitting models for Austin
#   Shape: (918, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (918, 12)
# Fitting GradientBoostingRegressor;                took 37.01 seconds
# Fitting XGBRegressor;                             took 385.05 seconds
# Took a total of 422.07 seconds to fit all models for circuit "Austin"
#
# Fitting models for Miami
#   Shape: (2160, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (2160, 12)
# Fitting GradientBoostingRegressor;                took 81.53 seconds
# Fitting XGBRegressor;                             took 403.79 seconds
# Took a total of 485.33 seconds to fit all models for circuit "Miami"
#
# Fitting models for Zandvoort
#   Shape: (5035, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (5035, 12)
# Fitting GradientBoostingRegressor;                took 183.69 seconds
# Fitting XGBRegressor;                             took 432.01 seconds
# Took a total of 615.71 seconds to fit all models for circuit "Zandvoort"
#
# Fitting models for Monte Carlo
#   Shape: (4244, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (4244, 12)
# Fitting GradientBoostingRegressor;                took 166.58 seconds
# Fitting XGBRegressor;                             took 414.74 seconds
# Took a total of 581.32 seconds to fit all models for circuit "Monte Carlo"
#
# Fitting models for Montreal
#   Shape: (4307, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (4307, 12)
# Fitting GradientBoostingRegressor;                took 161.92 seconds
# Fitting XGBRegressor;                             took 416.26 seconds
# Took a total of 578.18 seconds to fit all models for circuit "Montreal"
#
# Fitting models for Monza
#   Shape: (3898, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (3898, 12)
# Fitting GradientBoostingRegressor;                took 146.5 seconds
# Fitting XGBRegressor;                             took 416.73 seconds
# Took a total of 563.24 seconds to fit all models for circuit "Monza"
#
# Fitting models for Melbourne
#   Shape: (3071, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (3071, 12)
# Fitting GradientBoostingRegressor;                took 111.66 seconds
# Fitting XGBRegressor;                             took 417.55 seconds
# Took a total of 529.22 seconds to fit all models for circuit "Melbourne"
#
# Fitting models for Spielberg
#   Shape: (1124, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (1124, 12)
# Fitting GradientBoostingRegressor;                took 45.42 seconds
# Fitting XGBRegressor;                             took 386.95 seconds
# Took a total of 432.38 seconds to fit all models for circuit "Spielberg"
#
# Fitting models for Sakhir
#   Shape: (4415, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (4415, 12)
# Fitting GradientBoostingRegressor;                took 153.08 seconds
# Fitting XGBRegressor;                             took 418.37 seconds
# Took a total of 571.46 seconds to fit all models for circuit "Sakhir"
#
# Fitting models for Imola
#   Shape: (2442, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (2442, 12)
# Fitting GradientBoostingRegressor;                took 93.72 seconds
# Fitting XGBRegressor;                             took 405.48 seconds
# Took a total of 499.21 seconds to fit all models for circuit "Imola"
#
# Fitting models for Baku
#   Shape: (2734, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (2734, 12)
# Fitting GradientBoostingRegressor;                took 103.15 seconds
# Fitting XGBRegressor;                             took 414.32 seconds
# Took a total of 517.47 seconds to fit all models for circuit "Baku"
#
# Fitting models for Mexico City
#   Shape: (3843, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (3843, 12)
# Fitting GradientBoostingRegressor;                took 148.21 seconds
# Fitting XGBRegressor;                             took 402.05 seconds
# Took a total of 550.27 seconds to fit all models for circuit "Mexico City"
#
# Fitting models for Jeddah
#   Shape: (3430, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (3430, 12)
# Fitting GradientBoostingRegressor;                took 121.5 seconds
# Fitting XGBRegressor;                             took 406.15 seconds
# Took a total of 527.66 seconds to fit all models for circuit "Jeddah"
#
# Fitting models for Yas Marina Circuit
#   Shape: (3307, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (3307, 12)
# Fitting GradientBoostingRegressor;                took 122.31 seconds
# Fitting XGBRegressor;                             took 417.18 seconds
# Took a total of 539.49 seconds to fit all models for circuit "Yas Marina Circuit"
#
# Fitting models for Las Vegas
#   Shape: (1799, 12), Kolumny: ['IsPitLap', 'TyreLife', 'FreshTyre', 'LapNumber', 'AirTemp', 'Humidity', 'Pressure', 'Rainfall', 'TrackTemp', 'WindDirection', 'WindSpeed', 'CompoundNumeric']
#   Shape po imputacji: (1799, 12)
# Fitting GradientBoostingRegressor;                took 64.84 seconds
# Fitting XGBRegressor;                             took 399.67 seconds
# Took a total of 464.52 seconds to fit all models for circuit "Las Vegas"

# %%
context.catalog.save("second_phase_models", models_and_circuits)
# Out:
# [11/12/25 15:08:41] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=217106;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=80922;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py#243\243]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     INFO     Saving data to second_phase_models (PickleDataset)...             ]8;id=230208;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=488164;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py#1006\1006]8;;\

# %% [markdown]
# ## Results
# Below are the results of our testing. R^2 is used for score. XGBRegressor generally performs better, but for some circuits, GradientBoostingRegressor gets better scores.

# %%
# Show scores for each GridSearch and circuit
all_scores = {}
for key in models_and_circuits.keys():
    scores = {}
    for circuit, model in models_and_circuits[key].items():
        scores[circuit] = model.best_score_
    all_scores[key] = scores

all_scores: pd.DataFrame = pd.DataFrame(all_scores)

all_scores
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                     GradientBoostingRegressor  XGBRegressor
# Catalunya                            0.706168      0.724938
# Spa-Francorchamps                    0.918907      0.919926
# Silverstone                          0.785578      0.800788
# Singapore                            0.647672      0.741458
# Hungaroring                          0.655903      0.684192
# Suzuka                               0.836539      0.826470
# Paul Ricard                          0.887277      0.897035
# Austin                               0.920182      0.921024
# Miami                                0.818684      0.827875
# Zandvoort                            0.863794      0.870860
# Monte Carlo                          0.538924      0.681142
# Montreal                             0.860045      0.872057
# Monza                                0.636754      0.672160
# Melbourne                            0.862216      0.867142
# Spielberg                            0.953059      0.952850
# Sakhir                               0.713378      0.749446
# Imola                                0.840828      0.840996
# Baku                                 0.734176      0.726396
# Mexico City                          0.828270      0.861445
# Jeddah                               0.845293      0.843650
# Yas Marina Circuit                   0.826406      0.819814
# Las Vegas                            0.847125      0.853758

# %% [markdown]
# Overall statistics for both algorithms. XGBRegressor is generally better.

# %%
# Show score statistics for each model
# MinScore is very important. A good model should perform reasonably well for all tracks.
model_scores_df = pd.DataFrame(
    {
        "MeanScore": all_scores.mean(axis="index"),
        "MedianScore": all_scores.median(axis="index"),
        "ScoreVariance": all_scores.var(axis="index"),
        "MinScore": all_scores.min(axis="index"),
    }
)

model_scores_df.sort_values(by=["MeanScore"], ascending=False)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                            MeanScore  MedianScore  ScoreVariance  MinScore
# XGBRegressor                0.816156     0.834435       0.006849  0.672160
# GradientBoostingRegressor   0.796690     0.832405       0.011413  0.538924

# %%
# Drop BestModelType if it already exists
all_scores.drop(labels=["BestModelType"], axis="columns", inplace=True, errors="ignore")
all_scores["BestModelType"] = all_scores.idxmax(axis="columns")
all_scores
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                     GradientBoostingRegressor  XGBRegressor  \
# Catalunya                            0.706168      0.724938
# Spa-Francorchamps                    0.918907      0.919926
# Silverstone                          0.785578      0.800788
# Singapore                            0.647672      0.741458
# Hungaroring                          0.655903      0.684192
# Suzuka                               0.836539      0.826470
# Paul Ricard                          0.887277      0.897035
# Austin                               0.920182      0.921024
# Miami                                0.818684      0.827875
# Zandvoort                            0.863794      0.870860
# Monte Carlo                          0.538924      0.681142
# Montreal                             0.860045      0.872057
# Monza                                0.636754      0.672160
# Melbourne                            0.862216      0.867142
# Spielberg                            0.953059      0.952850
# Sakhir                               0.713378      0.749446
# Imola                                0.840828      0.840996
# Baku                                 0.734176      0.726396
# Mexico City                          0.828270      0.861445
# Jeddah                               0.845293      0.843650
# Yas Marina Circuit                   0.826406      0.819814
# Las Vegas                            0.847125      0.853758
#
#                                 BestModelType
# Catalunya                        XGBRegressor
# Spa-Francorchamps                XGBRegressor
# Silverstone                      XGBRegressor
# Singapore                        XGBRegressor
# Hungaroring                      XGBRegressor
# Suzuka              GradientBoostingRegressor
# Paul Ricard                      XGBRegressor
# Austin                           XGBRegressor
# Miami                            XGBRegressor
# Zandvoort                        XGBRegressor
# Monte Carlo                      XGBRegressor
# Montreal                         XGBRegressor
# Monza                            XGBRegressor
# Melbourne                        XGBRegressor
# Spielberg           GradientBoostingRegressor
# Sakhir                           XGBRegressor
# Imola                            XGBRegressor
# Baku                GradientBoostingRegressor
# Mexico City                      XGBRegressor
# Jeddah              GradientBoostingRegressor
# Yas Marina Circuit  GradientBoostingRegressor
# Las Vegas                        XGBRegressor

# %% [markdown]
# Finally, we export the chosen models to a file for further use. The file contains a Python dictionary, where the keys are circuit names, and the values are the best model for each track. For most circuits, that will be an XGBRegressor, for others — a GradientBoostingRegressor.

# %%
final_regressor_dictionary = {}
for circuit in all_scores.index:
    best_model_type = all_scores.loc[circuit, "BestModelType"]
    final_regressor_dictionary[circuit] = models_and_circuits[best_model_type][
        circuit
    ].best_estimator_

# %%
context.catalog.save("best_parameters", final_regressor_dictionary)
print("Zapisano słownik regresorów")
# Out:
# [11/12/25 15:08:42] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=403634;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=391794;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py#243\243]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     INFO     Saving data to best_parameters (PickleDataset)...                 ]8;id=839923;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=724854;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py#1006\1006]8;;\
# Zapisano słownik regresorów
