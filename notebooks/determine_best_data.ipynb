# %%
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project
from pathlib import Path
# Out:
# [10/29/25 13:53:29] INFO     Using                                                                  ]8;id=215713;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=18173;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/pyt
#                              hon3.11/site-packages/kedro/framework/project/rich_logging.yml' as
#                              logging configuration.

# %%
project_path = Path.cwd().parent
bootstrap_project(project_path)
print(f"Ścieżka projektu: {project_path}")
# Out:
# Ścieżka projektu: /Users/kacperziebacz/Desktop/f1-pitstop-advisor-v2

# %%
# tworzymy modele

# %%
for dataset in ['ex1', 'ex2']:
    with KedroSession.create(project_path=project_path) as session:
        context = session.load_context()
        data = context.catalog.load(dataset)
# Out:
# [10/29/25 13:53:29] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=752273;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=541509;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py#243\243]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [10/29/25 13:53:30] INFO     Loading data from ex1 (PickleDataset)...                          ]8;id=102439;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=179734;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=836496;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=71149;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro_telemetry/plugin.py#243\243]8;;\
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     INFO     Loading data from ex2 (PickleDataset)...                          ]8;id=741629;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=178877;file:///opt/homebrew/Caskroom/miniforge/base/envs/f1-pitstop-advisor/lib/python3.11/site-packages/kedro/io/data_catalog.py#1046\1046]8;;\
